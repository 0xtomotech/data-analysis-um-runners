# %% [markdown]
# ## Ultra Marathon Runners - An Exploratory Data Analysis

# %% [markdown]
# Data source: https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
# import libraries
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# /var/folders/_5/hcq3myc97jn9bf7mbp59_jn00000gn/T/ipykernel_16196/2789373578.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
# clean data
# Only USA races, 50km, or 50mi, 2020

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# combine 50km/50mi with isin
df[df['Event distance/length'].isin(['50mi', '50km'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# add 2020 year filter
df[(df['Event distance/length'].isin(['50mi', '50km'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
# test filtering for USA
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
# check if USA filter works on initial dataset
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# combine all filters together
df[(df['Event distance/length'].isin(['50mi', '50km'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
# USA, 2020, 50km, 50mi

df2 = df[(df['Event distance/length'].isin(['50mi', '50km'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')].copy()

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
# remove USA from event name
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# Clean up athlete age
df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# remove h from athlete performance
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#drop coloumns: Athlete Club, Athlete Country, Athlete year of birth, Athlete age catgeory
df2.drop(columns=['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], inplace=True)
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# clean up null values
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26090 entries, 2539945 to 2760961
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year of event              26090 non-null  int64
#  1   Event dates                26090 non-null  object
#  2   Event name                 26090 non-null  object
#  3   Event distance/length      26090 non-null  object
#  4   Event number of finishers  26090 non-null  int64
#  5   Athlete performance        26090 non-null  object
#  6   Athlete gender             26090 non-null  object
#  7   Athlete average speed      26090 non-null  object
#  8   Athlete ID                 26090 non-null  int64
#  9   athlete_age                25857 non-null  float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.2+ MB

# %%
df2[df2['athlete_age'].isna()]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# drop null values
df2.dropna(subset=['athlete_age'], inplace=True)
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
# check for duplicates
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
# reset index
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# fix types
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# rename coloumns
# Create a dictionary to map old column names to new column names
column_mapping = {
    'Year of event': 'year_of_event',
    'Event dates': 'event_dates',
    'Event name': 'event_name',
    'Event distance/length': 'event_distance_length',
    'Event number of finishers': 'event_number_of_finishers',
    'Athlete performance': 'athlete_performance',
    'Athlete gender': 'athlete_gender',
    'Athlete average speed': 'athlete_average_speed',
    'Athlete ID': 'athlete_id',
    'athlete_age': 'athlete_age'  # This one is already in the correct format
}

# Rename the columns
df2.rename(columns=column_mapping, inplace=True)

# Verify the new column names
print(df2.columns)
# Out:
# Index(['year_of_event', 'event_dates', 'event_name', 'event_distance_length',
#        'event_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_average_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
# Define the new column order
new_order = [
    'year_of_event',
    'event_dates',
    'event_name',
    'event_distance_length',
    'event_number_of_finishers',
    'athlete_id',
    'athlete_gender',
    'athlete_age',
    'athlete_performance',
    'athlete_average_speed'
]

# Rearrange the columns
df2 = df2[new_order]

# Verify the new column order
print(df2.columns)
df2.head()
# Out:
# Index(['year_of_event', 'event_dates', 'event_name', 'event_distance_length',
#        'event_number_of_finishers', 'athlete_id', 'athlete_gender',
#        'athlete_age', 'athlete_performance', 'athlete_average_speed'],
#       dtype='object')
#          year_of_event event_dates                                event_name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         event_distance_length  event_number_of_finishers  athlete_id  \
# 2539945                  50km                         20       71287
# 2539946                  50km                         20      629508
# ...

# %%
df2[df2['athlete_id'] == 222509]
# Out:
#          year_of_event event_dates                     event_name  \
# 2591482           2020  14.03.2020  Everglades 50 Mile Ultra Run
# 2616900           2020  22.02.2020       Manasota Track Club 50K
#
#         event_distance_length  event_number_of_finishers  athlete_id  \
# 2591482                  50mi                         40      222509
# 2616900                  50km                         36      222509
#
#         athlete_gender  athlete_age athlete_performance  athlete_average_speed
# 2591482              M           23             9:19:10                  8.634
# 2616900              M           23             4:49:16                 10.371

# %%
# charts and graphs

sns.histplot(df2['event_distance_length'])
# Out:
# <Axes: xlabel='event_distance_length', ylabel='Count'>

# %%
sns.histplot(df2, x='event_distance_length', hue='athlete_gender')
# Out:
# <Axes: xlabel='event_distance_length', ylabel='Count'>

# %%
sns.displot(df2[df2['event_distance_length'] == '50mi']['athlete_average_speed'])

# %%
sns.violinplot(data=df2, x='event_distance_length', y='athlete_average_speed', hue='athlete_gender')
# Out:
# <Axes: xlabel='event_distance_length', ylabel='athlete_average_speed'>

# %%
sns.violinplot(data=df2, x='event_distance_length', y='athlete_average_speed', hue='athlete_gender', split=True, inner='quartile', linewidth=1)
# Out:
# <Axes: xlabel='event_distance_length', ylabel='athlete_average_speed'>

# %%
df2.dtypes
# Out:
# year_of_event                  int64
# event_dates                   object
# event_name                    object
# event_distance_length         object
# event_number_of_finishers      int64
# athlete_id                     int64
# athlete_gender                object
# athlete_age                    int64
# athlete_performance           object
# athlete_average_speed        float64
# dtype: object

# %%
sns.lmplot(data=df2, x='athlete_age', y='athlete_average_speed', hue='athlete_gender')

# %%
# questions we want to answer based on data
# year_of_event                  int64
# event_dates                   object
# event_name                    object
# event_distance_length         object
# event_number_of_finishers      int64
# athlete_id                     int64
# athlete_gender                object
# athlete_age                    int64
# athlete_performance           object
# athlete_average_speed        float64

# %%
# difference in speed for 50km vs 50 mi, male to female
df2.groupby(['event_distance_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# event_distance_length  athlete_gender
# 50km                   F                 7.083011
#                        M                 7.738985
# 50mi                   F                 6.834371
#                        M                 7.257633
# Name: athlete_average_speed, dtype: float64

# %%
# what age groups are the best in 50mi Race, 20 races minimum
df2.query('event_distance_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).query('count >= 20').sort_values('mean', ascending=False)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182
# 40           7.310669    236
# 21           7.304658     38
# 20           7.293778     27
# 32           7.287969    162
# 39           7.283648    227
# 37           7.220493    221
# 27           7.201748    119
# 41           7.197017    179
# 45           7.130667    156
# 47           7.085410    156
# 44           7.052642    179
# 51           7.019379    124
# 46           6.897236    174
# 43           6.884225    187
# 52           6.847400    130
# ...

# %%
# what age groups are the worst in 50mi Race, 10 races minimum, top 10
df2.query('event_distance_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).query('count >= 10').sort_values('mean', ascending=True).head(10)
# Out:
#                  mean  count
# athlete_age
# 70           5.470667     12
# 65           5.934786     14
# 68           5.957500     10
# 67           6.114909     11
# 66           6.194300     10
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67

# %%
df2.head()
# Out:
#          year_of_event event_dates                                event_name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         event_distance_length  event_number_of_finishers  athlete_id  \
# 2539945                  50km                         20       71287
# 2539946                  50km                         20      629508
# 2539947                  50km                         20       64838
# 2539948                  50km                         20      704450
# 2539949                  50km                         20      810281
#
#         athlete_gender  athlete_age athlete_performance  athlete_average_speed
# ...

# %%
# Slower in summer than winter?

# spring 3-5
# summer 6-8
# fall 9-11
# winter 12-2

# split between two decimals

df2['race_month'] = df2['event_dates'].str.split('.').str.get(1).astype(int)
df2.head()
# Out:
# /var/folders/_5/hcq3myc97jn9bf7mbp59_jn00000gn/T/ipykernel_16196/1351600296.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['race_month'] = df2['event_dates'].str.split('.').str.get(1).astype(int)
#          year_of_event event_dates                                event_name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
# ...

# %%
df2.sample(5)
# Out:
#          year_of_event event_dates  \
# 2577474           2020  12.07.2020
# 2623951           2020  14.02.2020
# 2698785           2020  19.12.2020
# 2616903           2020  22.02.2020
# 2713814           2020  21.11.2020
#
#                                            event_name event_distance_length  \
# 2577474                           Last Call 50 Miler                   50mi
# 2623951  Jackpot Ultra Running Festival 50 Mile Race                   50mi
# 2698785                           Huff 50K Trail Run                   50km
# 2616903                      Manasota Track Club 50K                   50km
# 2713814                                  JFK 50 Mile                   50mi
#
#          event_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2577474                         36      272569              M           46
# 2623951                         16      809370              M           29
# ...

# %%
df2['race_season'] = df2['race_month'].apply(lambda x: 'spring' if x in [3, 4, 5] else 'summer' if x in [6, 7, 8] else 'fall' if x in [9, 10, 11] else 'winter')
df2.sample(5)
# Out:
# /var/folders/_5/hcq3myc97jn9bf7mbp59_jn00000gn/T/ipykernel_16196/2016336346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['race_season'] = df2['race_month'].apply(lambda x: 'spring' if x in [3, 4, 5] else 'summer' if x in [6, 7, 8] else 'fall' if x in [9, 10, 11] else 'winter')
#          year_of_event event_dates                          event_name  \
# 2716261           2020  14.11.2020     Upchuck 50K Trail Running Race
# 2548557           2020  25.01.2020                  Eldrith Trail Run
# 2602254           2020  06.03.2020     Chattanooga 50 Mile Trail Race
# 2707542           2020  05.12.2020  The Fall 50 Mile Ultra Trail Race
# 2634479           2020  03.10.2020       Bull Mountain 50 Km Epic Run
#
# ...

# %%
df2.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                  mean  count
# race_season
# spring       7.684430   3294
# winter       7.518187  11595
# fall         7.406619   8315
# summer       6.869336   2653

# %%
# 50 miler only
df2.query('event_distance_length == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                  mean  count
# race_season
# fall         7.511585   1997
# spring       7.082557    836
# winter       7.048442   1977
# summer       6.505776    817
